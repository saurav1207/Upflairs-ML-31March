# %%
# !python -m pip install numpy
# !pip install numpy
# Out:
# ...
#      ---------------------------------------- 0.0/14.8 MB ? eta -:--:--
#      ---------------------------------------- 0.1/14.8 MB 1.3 MB/s eta 0:00:12
#      ---------------------------------------- 0.1/14.8 MB 2.2 MB/s eta 0:00:07
#      ---------------------------------------- 0.1/14.8 MB 2.2 MB/s eta 0:00:07
#      ---------------------------------------- 0.1/14.8 MB 2.2 MB/s eta 0:00:07
#      ---------------------------------------- 0.1/14.8 MB 2.2 MB/s eta 0:00:07
#      --------------------------------------- 0.2/14.8 MB 583.1 kB/s eta 0:00:26
#       -------------------------------------- 0.3/14.8 MB 749.3 kB/s eta 0:00:20
#      - -------------------------------------- 0.4/14.8 MB 1.1 MB/s eta 0:00:13
#      - -------------------------------------- 0.6/14.8 MB 1.4 MB/s eta 0:00:11
#      -- ------------------------------------- 0.8/14.8 MB 1.6 MB/s eta 0:00:09
#      -- ------------------------------------- 0.9/14.8 MB 1.6 MB/s eta 0:00:09
# ...

# %%
# !pip install pandas
# Out:
# ...
#      ---------------------------------------- 0.0/11.2 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.2 MB 1.4 MB/s eta 0:00:09
#      ---------------------------------------- 0.1/11.2 MB 1.1 MB/s eta 0:00:11
#       --------------------------------------- 0.2/11.2 MB 1.1 MB/s eta 0:00:10
#       --------------------------------------- 0.2/11.2 MB 1.1 MB/s eta 0:00:10
#      - -------------------------------------- 0.3/11.2 MB 1.4 MB/s eta 0:00:09
#      - -------------------------------------- 0.4/11.2 MB 1.5 MB/s eta 0:00:08
#      - -------------------------------------- 0.4/11.2 MB 1.5 MB/s eta 0:00:08
#      -- ------------------------------------- 0.6/11.2 MB 1.5 MB/s eta 0:00:07
#      -- ------------------------------------- 0.8/11.2 MB 1.6 MB/s eta 0:00:07
#      --- ------------------------------------ 0.9/11.2 MB 1.7 MB/s eta 0:00:07
#      --- ------------------------------------ 0.9/11.2 MB 1.7 MB/s eta 0:00:07
# ...

# %%
# Working With Python Modules

# %%
import numpy

# %%
numpy.version.version
# Out:
# '1.24.2'

# %%
import keyword

# %%
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
# here i want to write command in short than i can use "as" it give me to keep short name of function  
import keyword as kw
kw.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
from keyword import kwlist, iskeyword as isk
kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
isk('if')
# Out:
# True

# %%
import numpy as np

# %%
a = np.array([]) # empty data set
a
# it create an empty araay 
# array([], dtype=float64)
# Out:
# array([], dtype=float64)

# %%
b = np.array([3,4,5,6,7])
b
# Out:
# array([3, 4, 5, 6, 7])

# %%
len(a)
# Out:
# 0

# %%
len(a),len(b)
# Out:
# (0, 5)

# %%
# ATTRIBUTE THAT HELPFUL IN NUMPPY

# a.dtype
# b.dtype
# b.shape
# b.size
# a.shape
# a.ndim
# b.ndim

# %%
# CREATING A 2-D ARRAY 

c = np.array([[1,3,4], [5,6,7], [7,8,9], [10,11,12]])  # Here it is important that keep in mind that inside the array same length 
c

# sabse bahar vala bracket denote "no of rows"
# jab main bahar vaale bracket se ek ander aya toh  "no of columns"
# Out:
# array([[ 1,  3,  4],
#        [ 5,  6,  7],
#        [ 7,  8,  9],
#        [10, 11, 12]])

# %%
c.shape

# (4, 3) --> 4 rows and 3 column
# Out:
# (4, 3)

# %%
# I want to creagte a dimension 4 X 3 X 1
d = np.array([[[1],[3],[4]], [[5],[6],[7]], [[7],[8],[9]], [[10],[11],[12]]]) 
d


# [] sabse bahar vala bracket denote "no of rows"
# [[]]jab main bahar vaale bracket se ek ander aya toh  "no of columns"
# [[[]]] ab
# Out:
# array([[[ 1],
#         [ 3],
#         [ 4]],
#
#        [[ 5],
#         [ 6],
#         [ 7]],
#
#        [[ 7],
#         [ 8],
#         [ 9]],
#
#        [[10],
#         [11],
#         [12]]])

# %%
d.shape
# Out:
# (4, 3, 1)

# %%
# I want to creagte a dimension 4 X 3 X 2
e = np.array([[[1,2],[3,4],[4,2]], [[5,1],[6,2],[7,9]], [[4,7],[3,8],[5,9]], [[7,10],[8,11],[9,12]]]) 
e
# Out:
# array([[[ 1,  2],
#         [ 3,  4],
#         [ 4,  2]],
#
#        [[ 5,  1],
#         [ 6,  2],
#         [ 7,  9]],
#
#        [[ 4,  7],
#         [ 3,  8],
#         [ 5,  9]],
#
#        [[ 7, 10],
#         [ 8, 11],
#         [ 9, 12]]])

# %%
e.shape
# Out:
# (4, 3, 2)

# %%
c.sum(axis=1)
# Out:
# array([ 8, 18, 24, 33])

# %%
c.mean(axis=1)
# Out:
# array([ 2.66666667,  6.        ,  8.        , 11.        ])

# %%
# how can i access the from dimension 
# if i want to access more than one element fro matrix than i can use "scripting"

# indexing, slicing, and third one is scpriting 

# c[0][1]
# c[0:2, -1]
# c[0:2, -1:]
