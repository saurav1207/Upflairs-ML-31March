# %%
import cv2
import skimage as ski
import matplotlib.pyplot as plt

# %%
img = cv2.imread('Image1.png') #it read the image with the help of opencv
cv2.imshow('titles', img) #in between quote we can write any sring it show above with image 
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img1 = plt.imread('Image1.png')
plt.imshow(img1)
